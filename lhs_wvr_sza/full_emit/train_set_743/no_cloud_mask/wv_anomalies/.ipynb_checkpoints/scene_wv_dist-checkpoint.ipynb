# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import model_assessment

# %%
data = np.load('../train_no_clouds.npz')
refls = data['output_rfl']
wv = data['output_wv']
fids = data['output_idx']

values, counts = np.unique(fids, return_counts=True)
scenes = np.split(refls, 743)
wv_by_scene = np.split(wv, 743)
scenes = np.array(scenes)
wv_by_scene = np.array(wv_by_scene)

print(scenes.shape)
print(wv_by_scene.shape)
# Out:
# (743, 1242, 285)
# (743, 1242)

# %%
plt.hist(wv_by_scene.flatten())
# Out:
# (array([5.41000e+02, 2.70800e+03, 9.14072e+05, 2.38700e+03, 9.82000e+02,
#         3.15000e+02, 1.29500e+03, 1.64000e+02, 1.68000e+02, 1.74000e+02]),
#  array([-18.10269928,  -9.79184036,  -1.48098145,   6.82987747,
#          15.14073639,  23.45159531,  31.76245422,  40.07331314,
#          48.38417206,  56.69503098,  65.00588989]),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(wv_by_scene)
plt.colorbar()

# %%
plt.imshow(wv_by_scene, vmin = -10, vmax = 20)
plt.colorbar()
yticks = range(0, 750, 75)
plt.yticks(yticks)
plt.xticks(range(0, 1300, 100), rotation = 'vertical')
plt.xlabel('Crosstrack Pixel Number')
plt.ylabel('Scene Number')
plt.title('WV for Individual Scene (all TCFs) Crosstracks');

# %%
for i in range(150):
    plt.plot(wv_by_scene[i])

# %%
for i in range(150, 300, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(300, 450, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(450, 600, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(600, 743, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(743):
    plt.plot(wv_by_scene[i])
plt.yticks([-20, -15, -10, -5, 0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60])
plt.xticks([0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300])
plt.ylabel('Water Vapor (g/cm^2)')
plt.xlabel('Crosstrack Pixel Number')
plt.title('Atmospheric Water Vapor Values for Individual Scene ( < 50% TCF) Downtracks');
