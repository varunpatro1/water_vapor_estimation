# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys
import math
import seaborn as sns

parent_dir = os.path.dirname(os.path.realpath('../../../../analysis'))


# Add the parent directory to sys.path
sys.path.append(parent_dir)

import analysis.model_assessment
import analysis.train_data_analysis
from analysis.model_assessment import *
from analysis.per_scene_scatter import *
from scipy.stats import linregress

# %%
fnames = ['../../../../../lhs_wvr_sza/model_results/train_set_1285/scene_cloud_mask/all_dt_6_285.npz', '../../../../../lhs_wvr_sza/model_results/train_set_1285/scene_cloud_mask/all_rf_6_285.npz', '../../../../../lhs_wvr_sza/model_results/train_set_1285/scene_cloud_mask/all_mlpreg_6_285.npz']

# %%
plot_scatter_test_pred_all_models(fnames)
# Out:
# (114264,)
# (114264,)
# (114264,)
# (114264,)
# (114264,)
# (114264,)

# %%
plot_range_scatter_all_models(fnames, mode = 'absolute')
