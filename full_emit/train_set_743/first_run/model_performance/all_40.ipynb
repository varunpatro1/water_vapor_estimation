# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys

parent_dir = os.path.dirname(os.path.realpath('.../analysis'))

# Add the parent directory to sys.path
sys.path.append(parent_dir)

# Import the module from the parent directory
import analysis.model_assessment
import analysis.train_data_analysis

# %%
path = '../../model_results/first_run/all_dt_6_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178848,)
# test shape:  (178848,)
# train shape:  (712908,)
# 0.5725669864842807

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_DT_6_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_DT_6_40')

# %%
path = '../../model_results/first_run/all_rf_6_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178848,)
# test shape:  (178848,)
# train shape:  (712908,)
# 0.3408705006644895

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_RF_6_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_RF_6_40')

# %%
path = '../../model_results/first_run/all_mlpreg_6_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178848,)
# test shape:  (178848,)
# train shape:  (712908,)
# 0.22479599560161392

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_MLPREG_6_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_MLPREG_6_40')

# %%
path = '../../model_results/first_run/all_dt_5_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161460,)
# test shape:  (161460,)
# train shape:  (644598,)
# 0.2803244243856386

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_DT_5_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_DT_5_40')

# %%
path = '../../model_results/first_run/all_rf_5_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161460,)
# test shape:  (161460,)
# train shape:  (644598,)
# 0.15091630810359283

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_RF_5_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_RF_5_40')

# %%
path = '../../model_results/first_run/all_mlpreg_5_40.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161460,)
# test shape:  (161460,)
# train shape:  (644598,)
# 0.10844972664693178

# %%
analysis.model_assessment.compare_train_test_pred(y_train, y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for ALL_MLPREG_5_40')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for ALL_MLPREG_5_40')
