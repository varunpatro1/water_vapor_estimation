# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys
import math
import seaborn as sns

parent_dir = os.path.dirname(os.path.realpath('../../analysis'))


# Add the parent directory to sys.path
sys.path.append(parent_dir)

# Import the module from the parent directory
import analysis.model_assessment
import analysis.train_data_analysis
from analysis.model_assessment import *
from analysis.plot_range_scatter import *
from scipy.stats import linregress

# %%
fnames_dt = ['../../../model_results/train_set_743/second_run/all_dt_6_285.npz', '../../../model_results/train_set_743/second_run/all_dt_6_40.npz', '../../../model_results/train_set_743/second_run/all_dt_5_285.npz', \
         '../../../model_results/train_set_743/second_run/all_dt_5_40.npz']

plot_scatter_permutations(fnames_dt, 'percentile')
# Out:
# Mean Squared Error:  0.12070699677163778
# R-Squared of Fit:  0.3701600545715291
# Mean Squared Error:  0.11620105708112208
# R-Squared of Fit:  0.4037536903082797
# Mean Squared Error:  0.08506907708077883
# R-Squared of Fit:  0.4969640884116823
# Mean Squared Error:  0.10096779751522122
# R-Squared of Fit:  0.46442621687803637

# %%
fnames_rf = ['../../../model_results/train_set_743/second_run/all_rf_6_285.npz', '../../../model_results/train_set_743/second_run/all_rf_6_40.npz', '../../../model_results/train_set_743/second_run/all_rf_5_285.npz', \
         '../../../model_results/train_set_743/second_run/all_rf_5_40.npz']

plot_scatter_permutations(fnames_rf, 'percentile')
# Out:
# Mean Squared Error:  0.051081492123856514
# R-Squared of Fit:  0.5267867609903332
# Mean Squared Error:  0.04049598066219309
# R-Squared of Fit:  0.5505129599368472
# Mean Squared Error:  0.0468928135189091
# R-Squared of Fit:  0.6591741851169981
# Mean Squared Error:  0.04427752813648638
# R-Squared of Fit:  0.6292918804285511

# %%
fnames_mlpreg = ['../../../model_results/train_set_743/second_run/all_mlpreg_6_285.npz', '../../../model_results/train_set_743/second_run/all_mlpreg_6_40.npz', '../../../model_results/train_set_743/second_run/all_mlpreg_5_285.npz', \
         '../../../model_results/train_set_743/second_run/all_mlpreg_5_40.npz']

plot_scatter_permutations(fnames_mlpreg, 'percentile')
# Out:
# Mean Squared Error:  0.12678171399950966
# R-Squared of Fit:  0.3572169657152128
# Mean Squared Error:  0.09705042003497517
# R-Squared of Fit:  0.3785486126972173
# Mean Squared Error:  0.03882901859824844
# R-Squared of Fit:  0.5207271522733599
# Mean Squared Error:  0.07408673198457394
# R-Squared of Fit:  0.5074224426457331

# %%
fnames_dt = ['../../../model_results/train_set_743/second_run/all_dt_6_285.npz', '../../../model_results/train_set_743/second_run/all_dt_6_40.npz', '../../../model_results/train_set_743/second_run/all_dt_5_285.npz', \
         '../../../model_results/train_set_743/second_run/all_dt_5_40.npz']

plot_scatter_permutations(fnames_dt, 'absolute')
# Out:
# Mean Squared Error:  5.426252677494151
# R-Squared of Fit:  0.6133614370722545
# Mean Squared Error:  6.946976681265635
# R-Squared of Fit:  0.5127340916764374
# Mean Squared Error:  3.0930802529017383
# R-Squared of Fit:  0.728344352244294
# Mean Squared Error:  4.965226436815372
# R-Squared of Fit:  0.5303993920170471

# %%
plot_scatter_permutations(fnames_rf, 'absolute')
# Out:
# Mean Squared Error:  0.8974069600921233
# R-Squared of Fit:  0.876500733226976
# Mean Squared Error:  1.477135411412302
# R-Squared of Fit:  0.776317492181694
# Mean Squared Error:  0.5254786479128603
# R-Squared of Fit:  0.9198683321946164
# Mean Squared Error:  0.7862673188061826
# R-Squared of Fit:  0.8805355726178142

# %%
plot_scatter_permutations(fnames_mlpreg, 'absolute')
# Out:
# Mean Squared Error:  0.999312862163582
# R-Squared of Fit:  0.8296680295466722
# Mean Squared Error:  1.1450023780073784
# R-Squared of Fit:  0.8090938278509722
# Mean Squared Error:  0.2646672807031482
# R-Squared of Fit:  0.9418496726663852
# Mean Squared Error:  0.4962260065495272
# R-Squared of Fit:  0.9042624560635493
