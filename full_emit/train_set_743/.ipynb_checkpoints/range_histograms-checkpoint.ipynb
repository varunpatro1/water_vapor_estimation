# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys
import math

parent_dir = os.path.dirname(os.path.realpath('../analysis'))

# Add the parent directory to sys.path
sys.path.append(parent_dir)

# Import the module from the parent directory
import analysis.model_assessment
import analysis.train_data_analysis
from analysis.model_assessment import *

# %%
path = '../../model_results/second_run/all_dt_6_285.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 path = '../../model_results/first_run/all_dt_6_285.npz'
# ----> 2 data = np.load(path)
#       3 y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
#       4 plot_range_hist(y_test, y_pred, path, 'percentile')
#
# File ~\AppData\Local\anaconda3\envs\isofit_env\lib\site-packages\numpy\lib\npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../model_results/first_run/all_dt_6_285.npz'

# %%
path = '../../model_results/first_run/all_dt_6.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  5.426252677494151

# %%
path = '../../model_results/first_run/all_dt_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# Mean Squared Error:  0.08506907708077883

# %%
path = '../../model_results/first_run/all_dt_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  3.0930802529017383

# %%
path = '../../model_results/first_run/all_rf_6.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# Mean Squared Error:  0.051081492123856514

# %%
path = '../../model_results/first_run/all_rf_6.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  0.8974069600921233

# %%
path = '../../model_results/first_run/all_rf_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# Mean Squared Error:  0.0468928135189091

# %%
path = '../../model_results/first_run/all_rf_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  0.5254786479128603

# %%
path = '../../model_results/first_run/all_mlpreg_6.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# Mean Squared Error:  0.12678171399950966

# %%
path = '../../model_results/first_run/all_mlpreg_6.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  0.999312862163582

# %%
path = '../../model_results/first_run/all_mlpreg_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'percentile')
# Out:
# Mean Squared Error:  0.03882901859824844

# %%
path = '../../model_results/first_run/all_mlpreg_5.npz'
data = np.load(path)
y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']
plot_range_hist(y_test, y_pred, path, 'absolute')
# Out:
# Mean Squared Error:  0.2646672807031482
