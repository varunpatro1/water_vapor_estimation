# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys
import math
import seaborn as sns

parent_dir = os.path.dirname(os.path.realpath('../analysis'))

# Add the parent directory to sys.path
sys.path.append(parent_dir)

# Import the module from the parent directory
import analysis.model_assessment
import analysis.train_data_analysis
from analysis.model_assessment import *

# %%
fnames = ['../../model_results/second_run/all_dt_6_285.npz', '../../model_results/second_run/all_dt_6_40.npz', '../../model_results/second_run/all_dt_5_285.npz', \
         '../../model_results/second_run/all_dt_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2.5, h_pad=4.0)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_2 = np.percentile(y_test, 0.02, axis=1)
    pred_2 = np.percentile(y_pred, 0.02, axis=1)
    test_98 = np.percentile(y_test, 0.98, axis=1)
    pred_98 = np.percentile(y_pred, 0.98, axis=1)
    
    test_ranges = np.subtract(test_98, test_2)
    pred_ranges = np.subtract(pred_98, pred_2)
    
    title = 'WVR Scatter (2nd - 98 percentiles) for ' + model_name

    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  0.12070699677163778
# R-Squared of Fit:  -22.85806443791914
# Mean Squared Error:  0.11620105708112208
# R-Squared of Fit:  -21.967453269014964
# Mean Squared Error:  0.08506907708077883
# R-Squared of Fit:  -14.225046033946766
# Mean Squared Error:  0.10096779751522122
# R-Squared of Fit:  -17.070483633621024

# %%
fnames = ['../../model_results/second_run/all_dt_6_285.npz', '../../model_results/second_run/all_dt_6_40.npz', '../../model_results/second_run/all_dt_5_285.npz', \
         '../../model_results/second_run/all_dt_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2, h_pad=3.5)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_ranges = np.max(y_test, axis = 1) - np.min(y_test, axis = 1)
    pred_ranges = np.max(y_pred, axis = 1) - np.min(y_pred, axis = 1)
    
    title = 'WVR Scatter (Abs Max - Abs Min) for ' + model_name
    
    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xticks(np.arange(7))
    axs[row, col].set_yticks(np.arange(7))
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  5.426252677494151
# R-Squared of Fit:  -2.198091203119112
# Mean Squared Error:  6.946976681265635
# R-Squared of Fit:  -3.094366099974742
# Mean Squared Error:  3.0930802529017383
# R-Squared of Fit:  -1.2031583318451848
# Mean Squared Error:  4.965226436815372
# R-Squared of Fit:  -2.5366621941041774

# %%
fnames = ['../../model_results/second_run/all_rf_6_285.npz', '../../model_results/second_run/all_rf_6_40.npz', '../../model_results/second_run/all_rf_5_285.npz', \
         '../../model_results/second_run/all_rf_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2.5, h_pad=4.0)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_2 = np.percentile(y_test, 0.02, axis=1)
    pred_2 = np.percentile(y_pred, 0.02, axis=1)
    test_98 = np.percentile(y_test, 0.98, axis=1)
    pred_98 = np.percentile(y_pred, 0.98, axis=1)
    
    test_ranges = np.subtract(test_98, test_2)
    pred_ranges = np.subtract(pred_98, pred_2)
    
    title = 'WVR Scatter (2nd - 98 percentiles) for ' + model_name

    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  0.051081492123856514
# R-Squared of Fit:  -9.096395099462734
# Mean Squared Error:  0.04049598066219309
# R-Squared of Fit:  -7.004140124065662
# Mean Squared Error:  0.0468928135189091
# R-Squared of Fit:  -7.3925354427994225
# Mean Squared Error:  0.04427752813648638
# R-Squared of Fit:  -6.924470645276294

# %%
fnames = ['../../model_results/second_run/all_rf_6_285.npz', '../../model_results/second_run/all_rf_6_40.npz', '../../model_results/second_run/all_rf_5_285.npz', \
         '../../model_results/second_run/all_rf_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2, h_pad=3.5)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_ranges = np.max(y_test, axis = 1) - np.min(y_test, axis = 1)
    pred_ranges = np.max(y_pred, axis = 1) - np.min(y_pred, axis = 1)
    
    title = 'WVR Scatter (Abs Max - Abs Min) for ' + model_name
    
    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xticks(np.arange(7))
    axs[row, col].set_yticks(np.arange(7))
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  0.8974069600921233
# R-Squared of Fit:  0.47109184270168425
# Mean Squared Error:  1.477135411412302
# R-Squared of Fit:  0.1294150778037546
# Mean Squared Error:  0.5254786479128603
# R-Squared of Fit:  0.6257088188158502
# Mean Squared Error:  0.7862673188061826
# R-Squared of Fit:  0.43995265145147644

# %%
fnames = ['../../model_results/second_run/all_mlpreg_6_285.npz', '../../model_results/second_run/all_mlpreg_6_40.npz', '../../model_results/second_run/all_mlpreg_5_285.npz', \
         '../../model_results/second_run/all_mlpreg_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2.5, h_pad=4.0)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_2 = np.percentile(y_test, 0.02, axis=1)
    pred_2 = np.percentile(y_pred, 0.02, axis=1)
    test_98 = np.percentile(y_test, 0.98, axis=1)
    pred_98 = np.percentile(y_pred, 0.98, axis=1)
    
    test_ranges = np.subtract(test_98, test_2)
    pred_ranges = np.subtract(pred_98, pred_2)
    
    title = 'WVR Scatter (2nd - 98 percentiles) for ' + model_name

    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  0.12678171399950966
# R-Squared of Fit:  -24.05874873080148
# Mean Squared Error:  0.09705042003497517
# R-Squared of Fit:  -18.18227805221651
# Mean Squared Error:  0.03882901859824844
# R-Squared of Fit:  -5.949335950241335
# Mean Squared Error:  0.07408673198457394
# R-Squared of Fit:  -12.25950561211246

# %%
fnames = ['../../model_results/second_run/all_mlpreg_6_285.npz', '../../model_results/second_run/all_mlpreg_6_40.npz', '../../model_results/second_run/all_mlpreg_5_285.npz', \
         '../../model_results/second_run/all_mlpreg_5_40.npz']

fig, axs = plt.subplots(2, 2, figsize = (10, 8))
fig.tight_layout(pad=0.4, w_pad=2, h_pad=3.5)

row = 0
col = 0

for i in range(len(fnames)):

    if col == 2:
        col = 0
        row+=1

    path = fnames[i]
    data = np.load(path)
    y_pred, y_test, y_train = data['arr_0'], data['arr_1'], data['arr_2']

    model_name = path[path.rfind('/')+1: path.rfind('.')].upper()
    
    crosstrack_pixel_length = 1242
    num_test_scenes = math.floor(y_test.shape[0] / crosstrack_pixel_length)
    y_test = y_test.reshape((num_test_scenes, crosstrack_pixel_length))
    y_pred = y_pred.reshape((num_test_scenes, crosstrack_pixel_length))
    
    test_ranges = np.max(y_test, axis = 1) - np.min(y_test, axis = 1)
    pred_ranges = np.max(y_pred, axis = 1) - np.min(y_pred, axis = 1)
    
    title = 'WVR Scatter (Abs Max - Abs Min) for ' + model_name
    
    mse = mean_squared_error(test_ranges, pred_ranges)
    r2 = r2_score(test_ranges, pred_ranges)
    print('Mean Squared Error: ', mse)
    print('R-Squared of Fit: ', r2)

    #m, b = np.polyfit(test_ranges, pred_ranges, 1)
    #plt.plot(test_ranges, m*test_ranges+b)
    axs[row, col].scatter(test_ranges, pred_ranges, alpha = 0.5)
    axs[row, col].set_title(title);
    axs[row, col].set_xticks(np.arange(7))
    axs[row, col].set_yticks(np.arange(7))
    axs[row, col].set_xlabel('Actual WV Ranges (g/cm^2)');
    axs[row, col].set_ylabel('Predicted WV Ranges (g/cm^2)');

    col+=1
# Out:
# Mean Squared Error:  0.999312862163582
# R-Squared of Fit:  0.4110311731511552
# Mean Squared Error:  1.1450023780073784
# R-Squared of Fit:  0.3251655884283491
# Mean Squared Error:  0.2646672807031482
# R-Squared of Fit:  0.8114811524528286
# Mean Squared Error:  0.4962260065495272
# R-Squared of Fit:  0.6465450711205374
