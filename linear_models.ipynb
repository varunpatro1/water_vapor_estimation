# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
refls = np.loadtxt('../EMIT-scenes/refl_2k.txt')
wv = np.loadtxt('../EMIT-scenes/wv_2k.txt')
df = pd.DataFrame(refls)
df['wv'] = wv
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)
X_train.shape
# Out:
# (7000, 285)

# %%
lr = LinearRegression().fit(X_train, y_train)

# %%
y_pred = lr.predict(X_test)
plt.hist(y_test, alpha = 0.7, label = 'Actual')
plt.hist(y_pred, alpha = 0.7, label = 'Predicted')
plt.legend()
plt.xlabel('Atmospheric WV (g/cm^2)')
plt.ylabel('Frequency')
plt.title('Default Linear Regression Regression 2k sample')
# Out:
# Text(0.5, 1.0, 'Default Linear Regression Regression 2k sample')

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(3)
poly.fit(X_train, y_train)
# Out:
# PolynomialFeatures(degree=3)

# %%
y_pred = poly.predict(X_test)
plt.hist(y_test, alpha = 0.7, label = 'Actual')
plt.hist(y_pred, alpha = 0.7, label = 'Predicted')
plt.legend()
plt.xlabel('Atmospheric WV (g/cm^2)')
plt.ylabel('Frequency')
plt.title('Default Polynomial Regression Regression 2k sample')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y_pred = poly.predict(X_test)
#       2 plt.hist(y_test, alpha = 0.7, label = 'Actual')
#       3 plt.hist(y_pred, alpha = 0.7, label = 'Predicted')
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'predict'
