# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
parent_dir = os.path.dirname(os.path.realpath('../analysis'))
sys.path.append(parent_dir)
import analysis.disp_h2o_data

# %%
data = np.load('../../2_scene_wv_mask.npz')
wv = data['output_wv'].reshape((2, 1280, 1242))
refls = data['output_rfl'].reshape((2, 1280, 1242, 285))
wv.shape
# Out:
# (2, 1280, 1242)

# %%
analysis.disp_h2o_data.plot_h2o_map(wv[0])

# %%
analysis.disp_h2o_data.plot_h2o_map(wv[1])
