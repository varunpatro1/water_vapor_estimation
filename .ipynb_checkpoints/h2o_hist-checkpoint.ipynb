# %%
import matplotlib.pyplot as plt
from spectral.io import envi

# %%
mask_header = envi.open('../west_africa_scene/wa_unortho/EMIT_L2A_MASK_001_20230321T150833_2308010_003_mask.hdr')
mask_data = mask_header.open_memmap(interleave = 'bip')
water_vapor = mask_data[:,:,6]

plt.imshow(water_vapor)
plt.colorbar()
plt.title("Atmospheric Water Vapor Levels (g/cm^2)")
plt.show()
# Out:
# C:\Users\vpatro\AppData\Local\anaconda3\envs\isofit_env\lib\site-packages\spectral\io\envi.py:175: UserWarning: Parameters with non-lowercase names encountered and converted to lowercase. To retain source file parameter name capitalization, set spectral.settings.envi_support_nonlowercase_params to True.
#   warnings.warn(msg)

# %%
plt.hist(water_vapor.flatten())
plt.ylabel('Frequency')
plt.xlabel('g/cm^2')
plt.title('Atmospheric Water Vapor Histogram')
plt.show()

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (10,10), constrained_layout = True)

im1 = axs[0].imshow(water_vapor)
fig.colorbar(im1)
axs[0].set_title("Atmospheric Water Vapor Levels (g/cm^2)")
fig.show()

im2 = axs[1].hist(water_vapor.flatten())
axs[1].set_ylabel('Frequency')
axs[1].set_xlabel('g/cm^2')
axs[1].set_title('Atmospheric Water Vapor Histogram')
fig.show()
# Out:
# C:\Users\vpatro\AppData\Local\Temp\ipykernel_9848\445474890.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\vpatro\AppData\Local\Temp\ipykernel_9848\445474890.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
