# %%
from sklearn.neural_network import MLPRegressor
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import assessment

# %%
refls = np.loadtxt('../EMIT-scenes/refl_2k.txt')
wv = np.loadtxt('../EMIT-scenes/wv_2k.txt')
df = pd.DataFrame(refls)
df['wv'] = wv
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# labels = [0, 0.25, 0.5, 0.75, 1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3, 3.25, 3.5, 3.75, 4, 4.25, 4.5, 4.75, 5, 5.25, 5.5, 5.75, 6]
# for i in range(len(labels)-1):
#     indices = np.logical_and(y >= labels[i], y < labels[i+1])
#     y[indices] = labels[i]
#
# y=y.astype('float64')

# %% [markdown]
# n, bins, patches = plt.hist(y, labels)
# plt.xticks(np.array(labels), np.array(labels), rotation = 'vertical')
# plt.title('Class Distribution of WV Values')
# plt.xlabel('Class')
# plt.ylabel('Frequency')

# %%
#bins

# %%
#n

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)

# %%
#clf = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(300, 300), activation = 'tanh', random_state=1)

# %%
#type(y_train[3])

# %%
#clf.fit(X_train, y_train)

# %%
clf = MLPRegressor(solver='adam', alpha=1e-5, hidden_layer_sizes=(300, 300), activation = 'tanh', random_state=1)

# %%
clf.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='tanh', alpha=1e-05, hidden_layer_sizes=(300, 300),
#              random_state=1)

# %%
y_pred = clf.predict(X_test)

# %%
assessment.plot_hist_and_scatter(y_test, y_pred, '2k MLPRegressor Histogram', '2k MLPRegressor Scatter')

# %%
indices = np.random.randint(0, y_test.shape[0], 100)
test, pred = assessment.random_select(y_test, y_pred, indices)
assessment.plot_bar_and_residuals(test, pred, '2k MLPReg on 100 Random Pixels', '2k MLPReg Residuals on 100 Random Pixels')

# %%
shortened_refls = refls[:, 60:100].copy()
df_short = pd.DataFrame(shortened_refls)
df_short['wv'] = wv
X = df_short.iloc[:, :-1]
y = df_short.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)
X_train.shape
# Out:
# (7000, 40)

# %%
clf = MLPRegressor(solver='adam', alpha=1e-5, hidden_layer_sizes=(50, 50), activation = 'tanh', random_state=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
assessment.plot_hist_and_scatter(y_test, y_pred, '2k MLPRegressor Histogram on Short Refl', '2k MLPRegressor Scatter on Short Refl')
