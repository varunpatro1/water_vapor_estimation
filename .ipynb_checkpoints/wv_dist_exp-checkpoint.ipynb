# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import model_assessment

# %%
data = np.load('../munged.npy.npz')
refls = data['output_rfl']
wv = data['output_wv']
fids = data['output_idx']

values, counts = np.unique(fids, return_counts=True)
scenes = np.split(refls, 594)
wv_by_scene = np.split(wv, 594)
scenes = np.array(scenes)
wv_by_scene = np.array(wv_by_scene)

print(scenes.shape)
print(wv_by_scene.shape)
# Out:
# (594, 1242, 285)
# (594, 1242)

# %%
plt.hist(wv_by_scene.flatten())
plt.xlim(0, 5)
# Out:
# (0.0, 5.0)

# %%
max(wv_by_scene.flatten())
# Out:
# 648.2577514648438

# %%
min(wv_by_scene.flatten())
# Out:
# -258.0062255859375

# %%
data = np.load('../train_set.npz')
refls = data['output_rfl']
wv = data['output_wv']
fids = data['output_idx']

values, counts = np.unique(fids, return_counts=True)
scenes = np.split(refls, 946)
wv_by_scene = np.split(wv, 946)
scenes = np.array(scenes)
wv_by_scene = np.array(wv_by_scene)

print(scenes.shape)
print(wv_by_scene.shape)
# Out:
# (946, 1242, 285)
# (946, 1242)

# %%
plt.hist(wv_by_scene.flatten())
plt.xlim(-50, 50)
# Out:
# (-50.0, 50.0)

# %%
plt.figure(figsize = ((8,8)))
plt.imshow(wv_by_scene[425:450], vmin = 0, vmax = 50)
plt.colorbar()

# %%
plt.plot(wv_by_scene[408, :])

# %%
fids = np.split(fids, 946)

# %%
fids = np.array(fids)

# %%
fids.shape
# Out:
# (946, 1242)

# %%
import pandas as pdf

# %%
df = pd.read_csv('../FIDs.txt')

# %%
fids = np.genfromtxt('../FIDs.txt')

# %%
df.shape
# Out:
# (945, 1)

# %%
(df.iloc[0]).shape
# Out:
# (1,)

# %%
df.iloc[0]
# Out:
# emit20230624t084456_o17506_s002    emit20230625t093133_o17606_s003
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# emit20230624t084456_o17506_s002    emit20230530t123909_o15009_s000
# Name: 1, dtype: object

# %%
df.iloc[408]
# Out:
# emit20230624t084456_o17506_s002    emit20220827t061153_o23904_s002
# Name: 408, dtype: object

# %%
plt.imshow(wv_by_scene, vmin = 0, vmax = 50)
plt.colorbar()

# %%
plt.imshow(wv_by_scene)
plt.colorbar()

# %%
plt.imshow(wv_by_scene, vmin = -50, vmax = 50)
plt.colorbar()

# %%
data = np.load('../train_no_clouds.npz')
refls = data['output_rfl']
wv = data['output_wv']
fids = data['output_idx']

values, counts = np.unique(fids, return_counts=True)
scenes = np.split(refls, 743)
wv_by_scene = np.split(wv, 743)
scenes = np.array(scenes)
wv_by_scene = np.array(wv_by_scene)

print(scenes.shape)
print(wv_by_scene.shape)
# Out:
# (743, 1242, 285)
# (743, 1242)

# %%
plt.hist(wv_by_scene.flatten())
# Out:
# (array([5.41000e+02, 2.70800e+03, 9.14072e+05, 2.38700e+03, 9.82000e+02,
#         3.15000e+02, 1.29500e+03, 1.64000e+02, 1.68000e+02, 1.74000e+02]),
#  array([-18.10269928,  -9.79184036,  -1.48098145,   6.82987747,
#          15.14073639,  23.45159531,  31.76245422,  40.07331314,
#          48.38417206,  56.69503098,  65.00588989]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(wv_by_scene.flatten())
plt.xlim(0, 5)
# Out:
# (0.0, 5.0)

# %%
plt.hist(wv_by_scene.flatten())
plt.xlim(-50, 50)
# Out:
# (-50.0, 50.0)

# %%
plt.imshow(wv_by_scene)
plt.colorbar()

# %%
plt.imshow(wv_by_scene, vmin = -10, vmax = 20)
plt.colorbar()

# %%
for i in range(100):
    plt.plot(wv_by_scene[i])

# %%
for i in range(100, 200, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(200, 300, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(300, 400, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(400, 500, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(500, 600, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(600, 700, 1):
    plt.plot(wv_by_scene[i])

# %%
for i in range(700, 743, 1):
    plt.plot(wv_by_scene[i])

# %%
exp = np.delete(wv_by_scene, np.where((wv_by_scene.any() > 6) | (wv_by_scene.any() < 0))[0], axis=0)

# %%
exp.shape
# Out:
# (743, 1242)

# %%
bad_scenes = np.where(wv_by_scene > 6, wv_by_scene < 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 bad_scenes = np.where(wv_by_scene > 6, wv_by_scene < 0)
#
# File <__array_function__ internals>:200, in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
bad_scenes.shape
# Out:
# (743, 1242)

# %%
exp = np.delete(wv_by_scene, bad_scenes, axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 exp = np.delete(wv_by_scene, bad_scenes, axis = 0)
#
# File <__array_function__ internals>:200, in delete(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\isofit_env\lib\site-packages\numpy\lib\function_base.py:5227, in delete(arr, obj, axis)
#    5225 if obj.dtype == bool:
#    5226     if obj.shape != (N,):
# -> 5227         raise ValueError('boolean array argument obj to delete '
#    5228                          'must be one dimensional and match the axis '
#    5229                          'length of {}'.format(N))
#    5231     # optimization, the other branch is slower
#    5232     keep = ~obj
#
# ValueError: boolean array argument obj to delete must be one dimensional and match the axis length of 743
