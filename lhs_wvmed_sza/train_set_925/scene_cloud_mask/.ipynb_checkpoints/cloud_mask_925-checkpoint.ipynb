# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error
import os
import sys
import math
import seaborn as sns

import analysis.model_assessment
import analysis.train_data_analysis
from analysis.model_assessment import *
from analysis.per_scene_scatter import *
from scipy.stats import linregress

# %%
fnames = ['../lhs_wvmed_sza/model_results/train_set_925/with_cloud_mask/all_dt_6_285.npz', '../lhs_wvmed_sza/model_results/train_set_925/with_cloud_mask/all_rf_6_285.npz', '../lhs_wvmed_sza/model_results/train_set_925/with_cloud_mask/all_mlpreg_6_285.npz']

# %%
plot_scatter_test_pred_all_models(fnames)
# Out:
# (111780,)
# (111780,)
# (111780,)
# (111780,)
# (111780,)
# (111780,)

# %%
plot_range_scatter_all_models(fnames, mode = 'absolute')

# %%
munged_data_path = '../munged_455.npz'

# %%
data = np.load(munged_data_path)
wv = data['output_wv']

# %%
wv.shape
# Out:
# (565110,)
