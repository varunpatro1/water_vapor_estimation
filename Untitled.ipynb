# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('../irr.npy')
irr_wl = data[:,0]
irr = data[:,1]

# %%
print(irr)
# Out:
# [92.78465455 97.055733   85.76996575 ...  4.92013196  4.93135421
#   4.90689737]

# %%
plt.plot(irr)
