# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from scipy.stats import gaussian_kde
from sklearn.metrics import mean_squared_error

import os
import sys

parent_dir = os.path.dirname(os.path.realpath('../../analysis'))

# Add the parent directory to sys.path
sys.path.append(parent_dir)

# Import the module from the parent directory
import analysis.model_assessment
import analysis.train_data_analysis

# %%
path = '../../../model_results/first_run/per_pixel/all_dt_6.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178352,)
# test shape:  (178352,)
# train shape:  (713404,)
# 0.15679173084625925

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_DT_6')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_DT_6')

# %%
path = '../../../model_results/first_run/per_pixel/all_dt_5.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161212,)
# test shape:  (161212,)
# train shape:  (644846,)
# 0.07172335181382573

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_DT_5')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_DT_5')

# %%
path = '../../../model_results/first_run/per_pixel/all_rf_6.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178352,)
# test shape:  (178352,)
# train shape:  (713404,)
# 0.07502939946461548

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_RF_6')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_RF_6')

# %%
path = '../../../model_results/first_run/per_pixel/all_rf_5.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161212,)
# test shape:  (161212,)
# train shape:  (644846,)
# 0.03464499871557152

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_RF_5')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_RF_5')

# %%
path = '../../../model_results/first_run/per_pixel/all_mlpreg_6.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (178352,)
# test shape:  (178352,)
# train shape:  (713404,)
# 0.06167884879405337

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_MLPREG_6')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_MLPREG_6')

# %%
path = '../../../model_results/first_run/per_pixel/all_mlpreg_5.npz'
data = np.load(path)
y_pred = data['arr_0']
y_test = data['arr_1']
y_train = data['arr_2']

print('pred shape: ', y_pred.shape)
print('test shape: ', y_test.shape)
print('train shape: ', y_train.shape)
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# pred shape:  (161212,)
# test shape:  (161212,)
# train shape:  (644846,)
# 0.03751004694714858

# %%
analysis.model_assessment.compare_test_pred(y_test, y_pred)

# %%
xy_model = np.vstack([y_test, y_pred])
z_model = gaussian_kde(xy_model)(xy_model)
plt.scatter(y_test, y_pred, c=z_model, s=1, cmap="jet")
plt.colorbar()
plt.xlabel('Actual WV')
plt.ylabel('Predicted WV')
plt.title('Gaussian KDE Scatter Plot for Per Pixel ALL_MLPREG_5')
# Out:
# Text(0.5, 1.0, 'Gaussian KDE Scatter Plot for Per Pixel ALL_MLPREG_5')
