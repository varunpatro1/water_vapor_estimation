# %%
from sklearn.svm import SVR
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import assessment

# %%
refls = np.loadtxt('../../EMIT-scenes/refl_2k.txt')
wv = np.loadtxt('../../EMIT-scenes/wv_2k.txt')
df = pd.DataFrame(refls)
df['wv'] = wv
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)
X_train.shape
# Out:
# (7000, 285)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)

svr = SVR()
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)

# %%
assessment.plot_hist_and_scatter(y_test, y_pred, '2k SVR Histogram', '2k SVR Scatter')

# %%
shortened_refls = refls[:, 60:100].copy()
df_short = pd.DataFrame(shortened_refls)
df_short['wv'] = wv
X = df_short.iloc[:, :-1]
y = df_short.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)
X_train.shape
# Out:
# (7000, 40)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 50)

svr = SVR()
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)

# %%
assessment.plot_hist_and_scatter(y_test, y_pred, '2k SVR Histogram', '2k SVR Scatter')
